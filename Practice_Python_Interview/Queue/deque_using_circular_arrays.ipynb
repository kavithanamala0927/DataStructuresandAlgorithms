# %%
class Deque:
    def __init__(self):
        self.size = 5
        self.front = -1
        self.rear = -1
        self.deque = [0]*self.size
    def enqueueFront(self, element):
        print ("Enqueue Front")
        if (self.front == self.rear + 1) or (self.front == 0 and self.rear == self.size-1):
            print ("OVER FLOW: Queue is Full")
        elif self.front == -1 and self.rear == -1:
            self.front = self.rear = 0
            self.deque[self.front] = element
        elif self.front == 0:
            self.front = self.size - 1
            self.deque[self.front] = element
        else:
            self.front -= 1
            self.deque[self.front] = element
    def enqueueRear(self, element):
        print ("Enqueue Rear")
        if (self.front == self.rear + 1 ) or (self.front == 0 and self.rear == self.size-1):
            print ("OVER FLOW: Queue is Full")
        elif self.front == -1 and self.rear == -1:
            self.front = self.rear = 0
            self.deque[self.rear] = element
        elif self.rear == self.size - 1:
            self.rear = 0
            self.deque[sel.rear] = element
        else:
            self.rear += 1
            self.deque[self.rear] = element
            
    def display(self):
        print ("Display Elements")
        if self.front == -1 and self.rear == -1:
            print ("UNDER FLOW: Queue is Empty")
        else:
            i = self.front
            while i != self.rear:
                print (self.deque[i])
                i = (i + 1) % self.size
            print (self.deque[self.rear])
    
    def getFront(self):
        print ("Get Front Element")
        if self.front == -1 and self.rear == -1:
            print ("Queue is Empty")
        else:
            print (self.deque[self.front])
            
    def getRear(self):
        print ("Get Rear Element")
        if self.front == -1 and self.rear == -1:
            print ("Queue is Empty")
        else:
            print (self.deque[self.rear])
    
    def dequeueFront(self):
        if self.front == -1 and self.rear == -1:
            print ("Queue is Empty")
        elif self.front == self.rear:
            print ("Dequeued Element", self.deque[self.front])
            self.front = self.rear = -1
        elif self.front == self.size - 1:
            print ("Dequeued Element", self.deque[self.front])
            self.front = 0
        else:
            print ("Dequeued Element", self.deque[self.front])
            self.front += 1
    
    def dequeueRear(self):
        if self.front == -1 and self.rear == -1:
            print ("Queue is Empty")
        elif self.front == self.rear:
            print ("Dequeued Element", self.deque[self.rear])
            self.front = self.rear = -1
        elif self.rear == 0:
            print ("Dequeued Element", self.deque[self.rear])
            self.rear = self.size - 1
        else:
            print ("Dequeued Element", self.deque[self.rear])
            self.rear -= 1

# %%
d = Deque()
d.enqueueFront(2)
d.enqueueFront(5)
d.enqueueRear(-1)
d.enqueueRear(0)
d.enqueueFront(7)
d.enqueueFront(4)
d.display()
d.getFront()
d.getRear()
d.dequeueFront()
d.dequeueRear()
d.dequeueRear()
d.dequeueFront()
d.dequeueFront()
d.dequeueRear()
# Out:
# Enqueue Front
# Enqueue Front
# Enqueue Rear
# Enqueue Rear
# Enqueue Front
# Enqueue Front
# OVER FLOW: Queue is Full
# Display Elements
# 7
# 5
# 2
# -1
# 0
# Get Front Element
# 7
# Get Rear Element
# 0
# Dequeued Element 7
# Dequeued Element 0
# Dequeued Element -1
# Dequeued Element 5
# Dequeued Element 2
# Queue is Empty
